# %% [markdown]
# ## import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## load data

# %%
train = pd.read_csv('data/split/train.csv')
validation = pd.read_csv('data/split/val.csv')
test = pd.read_csv('data/split/test.csv')

# %% [markdown]
# ## Overview of the dataset

# %%
train.shape, validation.shape, test.shape
# Out:
# ((170884, 31), (56960, 31), (56960, 31))

# %%
train.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  119191.0  2.052427 -0.133236 -1.740621  0.277935  0.337999 -0.826933
# 1   71750.0  1.220356 -0.159191 -0.444349 -0.094437  0.104457 -0.345790
# 2  151977.0  0.892824 -1.440698 -0.637940  3.912871  0.099291  2.433288
# 3   55709.0 -3.146021  2.247634  0.901397  0.146162 -2.109360 -0.148312
# 4   66654.0  1.194996 -0.007495  0.301285  0.750199 -0.297494 -0.405836
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.334629 -0.227039  0.267655  ... -0.006518  0.121300  0.037733 -0.356498
# 1  0.170867 -0.094996  0.187572  ... -0.088775 -0.364654 -0.140851 -0.707308
# 2 -0.308891  0.603227 -0.113826  ...  0.484969  0.487304 -0.122694 -0.598803
# 3 -1.533191  2.073663  0.499394  ...  0.050567 -0.037019  0.107000  0.392857
# 4  0.060410 -0.150482  0.400860  ... -0.234931 -0.545566 -0.089418 -0.064036
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
train.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 170879  137874.0 -2.314356 -1.477150  1.847313 -0.171896  0.929503  0.331769
# 170880    6559.0 -1.775889 -0.059785  2.371322 -2.628981  0.151867 -0.650695
# 170881  159020.0  1.879717 -0.557359 -0.426212 -0.041480 -0.240394  0.650912
# 170882   34859.0  0.879168 -0.494534  0.921462  1.565359 -0.967113  0.040689
# 170883  130876.0 -0.887659  1.538844 -0.540660 -0.550646 -0.246239 -1.235993
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 170879 -0.180278  0.296973  0.167303  ...  0.130012  0.319415  0.328271
# 170880 -0.433332  0.027177  3.370020  ... -0.097743  0.610452 -0.577917
# 170881 -0.818833  0.401973  1.405719  ... -0.072211 -0.025659  0.489627
# 170882 -0.338960  0.180871  1.020498  ...  0.060998  0.193461 -0.130303
# 170883  0.341516  0.622988 -0.264380  ... -0.202022 -0.576635  0.176584
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170884 entries, 0 to 170883
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    170884 non-null  float64
#  1   V1      170884 non-null  float64
#  2   V2      170884 non-null  float64
#  3   V3      170884 non-null  float64
#  4   V4      170884 non-null  float64
#  5   V5      170884 non-null  float64
#  6   V6      170884 non-null  float64
#  7   V7      170884 non-null  float64
#  8   V8      170884 non-null  float64
#  9   V9      170884 non-null  float64
#  10  V10     170884 non-null  float64
#  11  V11     170884 non-null  float64
#  12  V12     170884 non-null  float64
#  13  V13     170884 non-null  float64
#  14  V14     170884 non-null  float64
#  15  V15     170884 non-null  float64
#  16  V16     170884 non-null  float64
#  17  V17     170884 non-null  float64
#  18  V18     170884 non-null  float64
#  19  V19     170884 non-null  float64
# ...

# %%
train.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  170884.000000  170884.000000  170884.000000  170884.000000
# mean    94966.107886      -0.001070      -0.000904      -0.002722
# std     47464.723773       1.958944       1.650481       1.521820
# min         0.000000     -46.855047     -63.344698     -48.325589
# 25%     54348.000000      -0.922071      -0.599127      -0.896376
# 50%     84923.500000       0.016603       0.065839       0.177007
# 75%    139404.000000       1.316250       0.802518       1.028302
# max    172792.000000       2.451888      22.057729       4.226108
#
#                   V4             V5             V6             V7  \
# count  170884.000000  170884.000000  170884.000000  170884.000000
# mean       -0.002603       0.000151       0.000779      -0.000811
# std         1.416490       1.394123       1.338331       1.260122
# min        -5.683171    -113.743307     -23.496714     -43.557242
# ...

# %%
train.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
train.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
train.isnull().any(axis=1)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 170879    False
# 170880    False
# 170881    False
# 170882    False
# 170883    False
# Length: 170884, dtype: bool

# %%
# check if there is a duplicate 

duplicate_rows = train[train.duplicated()]
print("Deuplicated Rows:")
print(duplicate_rows)
# Out:
# Deuplicated Rows:
#             Time        V1        V2        V3        V4        V5        V6  \
# 1252    111137.0  2.103683  0.030503 -1.438682  0.328226  0.350531 -0.731849
# 3262    163152.0 -1.203617  1.574009  2.889277  3.381404  1.538663  3.698747
# 4204    122075.0 -1.724438  1.573767 -1.873367 -0.899698 -3.750201  1.042587
# 9492     39897.0  1.159796 -0.222744  1.126880  0.671504 -0.874117  0.209904
# 11566   163152.0 -1.196037  1.585949  2.883976  3.378471  1.511706  3.717077
# ...          ...       ...       ...       ...       ...       ...       ...
# 168798   85319.0 -5.536010  3.724987 -1.530908 -0.384255 -1.766212 -0.707323
# 169129   43153.0 -2.086016  2.203265  1.654339  2.941050 -1.683045  0.529728
# 169586   64936.0  1.150005 -0.058591  0.372711 -0.170626 -0.390476 -0.488250
# 170160   68780.0  0.488552 -0.922367  1.673494  3.003203 -1.465758  0.749788
# 170568  127594.0  1.715230  0.053932 -0.131504  3.708882  0.019145  0.650548
#
# ...

# %% [markdown]
# ### remove duplicates

# %%
train = train.drop_duplicates()
test = test.drop_duplicates()
validation = validation.drop_duplicates()
train.shape , validation.shape, test.shape
# Out:
# ((170436, 31), (56898, 31), (56908, 31))

# %%
# statistical summary of selected columns
cols =train[["Amount","Time","Class"]]
cols.describe().T
# Out:
#            count          mean           std  min       25%       50%  \
# Amount  170436.0     88.596637    256.942683  0.0      5.64     22.08
# Time    170436.0  94964.883252  47458.729255  0.0  54355.00  84923.50
# Class   170436.0      0.001743      0.041708  0.0      0.00      0.00
#
#                 75%        max
# Amount      77.8225   25691.16
# Time    139388.0000  172792.00
# Class        0.0000       1.00

# %%
# Calculate correlation matrix
corr = train.corr()

# Set up the matplotlib figure
plt.figure(figsize=(20, 16))  # You can adjust the size as needed

# Draw the heatmap
sns.heatmap(corr, cmap='Reds', annot=False, linewidths=0.5, square=True)

# Add title
plt.title("Correlation Matrix", fontsize=18)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### As expected, there is no notable correlation between features V1-V28. There are certain correlations between some of these features and Time (inverse correlation with V3) and Amount (direct correlation with V7 and V20, inverse correlation with V1 and V5).

# %%
train['Class'].value_counts()
# Out:
# Class
# 0    170139
# 1       297
# Name: count, dtype: int64

# %%
sns.countplot(data = train, x='Class')
# Out:
# <Axes: xlabel='Class', ylabel='count'>
